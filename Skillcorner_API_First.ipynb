# %% [markdown]
# # Skill Corner API Access

# %%
from skillcorner.client import SkillcornerClient
import json

# %%
# Credentials
with open('creds.json','r') as config_file:
    creds = json.load(config_file)

# %% [markdown]
# **Credentials**

# %%
client = SkillcornerClient(username=creds['username'],password=creds['password'])

# %% [markdown]
# ### Get all the competitions

# %%
client.get_competitions()
# Out:
# [{'id': 117,
#   'area': 'AFC',
#   'name': 'AFC Olympic Qualification Women Playoffs',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 115,
#   'area': 'AFC',
#   'name': 'AFF Suzuki Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 35,
#   'area': 'AFC',
#   'name': 'Asian Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 147,
#   'area': 'AFC',
#   'name': 'Champions League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 182,
#   'area': 'AFC',
#   'name': 'EAFF E-1 Football Championship',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 225,
#   'area': 'AFC',
#   'name': 'Gulf Cup of Nations',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 181,
#   'area': 'AFC',
#   'name': 'WC Qualification Asia',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 373,
#   'area': 'AFC',
#   'name': 'West Asia Championship U23',
#   'gender': 'male',
#   'age_group': 'U23'},
#  {'id': 311,
#   'area': 'ARG',
#   'name': 'Copa Argentina',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 70,
#   'area': 'ARG',
#   'name': 'Primera Division - 1st Phase',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 376,
#   'area': 'ARG',
#   'name': 'Primera Division - 2nd Phase',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 412,
#   'area': 'ARG',
#   'name': 'Primera Nacional',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 61,
#   'area': 'AUS',
#   'name': 'A-League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 410,
#   'area': 'AUS',
#   'name': 'A-League Women',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 103,
#   'area': 'AUT',
#   'name': '2. Liga',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 88,
#   'area': 'AUT',
#   'name': 'Bundesliga',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 119,
#   'area': 'BEL',
#   'name': '1B Pro League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 91,
#   'area': 'BEL',
#   'name': 'Beker Van Belgie',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 58,
#   'area': 'BEL',
#   'name': 'Belgium First Division A, Playoffs 2A',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 16,
#   'area': 'BEL',
#   'name': 'Pro League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 332,
#   'area': 'BGR',
#   'name': 'First League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 408,
#   'area': 'BIH',
#   'name': 'Premier League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 319,
#   'area': 'BOL',
#   'name': 'LFPB',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 413,
#   'area': 'BRA',
#   'name': 'Brasileirão Feminino',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 69,
#   'area': 'BRA',
#   'name': 'Campeonato Baiano',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 168,
#   'area': 'BRA',
#   'name': 'Carioca 1',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 167,
#   'area': 'BRA',
#   'name': 'CBF Brasileiro U20',
#   'gender': 'male',
#   'age_group': 'U20'},
#  {'id': 308,
#   'area': 'BRA',
#   'name': 'Copa do Brasil',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 341,
#   'area': 'BRA',
#   'name': 'Gaúcho 1',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 239,
#   'area': 'BRA',
#   'name': 'Mineiro 1',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 68,
#   'area': 'BRA',
#   'name': 'Paulista, Serie A1',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 169,
#   'area': 'BRA',
#   'name': 'São Paulo Youth Cup',
#   'gender': 'male',
#   'age_group': 'U20'},
#  {'id': 77,
#   'area': 'BRA',
#   'name': 'Série A',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 80,
#   'area': 'BRA',
#   'name': 'Série B',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 81,
#   'area': 'BRA',
#   'name': 'Série C',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 59,
#   'area': 'BRA',
#   'name': 'Série D',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 335,
#   'area': 'BRA',
#   'name': 'Supercopa do Brasil',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 37,
#   'area': 'CAF',
#   'name': 'Africa Cup of Nations',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 193,
#   'area': 'CAF',
#   'name': 'Africa Cup of Nations Qualification',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 197,
#   'area': 'CAF',
#   'name': 'African Nations Championship Qualification',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 201,
#   'area': 'CAF',
#   'name': 'African Olympic Qualifiers',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 317,
#   'area': 'CAF',
#   'name': 'African Super League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 213,
#   'area': 'CAF',
#   'name': 'Africa Women Cup of Nations',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 148,
#   'area': 'CAF',
#   'name': 'Champions League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 330,
#   'area': 'CAF',
#   'name': 'Champions League - Preliminary Rounds',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 195,
#   'area': 'CAF',
#   'name': 'COSAFA Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 32,
#   'area': 'CAF',
#   'name': 'FIFA World Cup Qualifier',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 118,
#   'area': 'CAF',
#   'name': 'U20 Africa Cup of Nations',
#   'gender': 'male',
#   'age_group': 'U20'},
#  {'id': 347,
#   'area': 'CAF',
#   'name': "Women's Olympic Qualifying",
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 203,
#   'area': 'CAN',
#   'name': 'Canadian Premier League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 57,
#   'area': 'CHI',
#   'name': 'Primera Division',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 47,
#   'area': 'CHN',
#   'name': 'Super League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 100,
#   'area': 'COL',
#   'name': 'Liga Dimayor',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 159,
#   'area': 'CONCACAF',
#   'name': 'Champions League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 214,
#   'area': 'CONCACAF',
#   'name': 'Copa America Femenina',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 33,
#   'area': 'CONCACAF',
#   'name': 'FIFA World Cup Qualifier',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 36,
#   'area': 'CONCACAF',
#   'name': 'Gold Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 234,
#   'area': 'CONCACAF',
#   'name': 'Gold Cup Qualification',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 346,
#   'area': 'CONCACAF',
#   'name': 'Leagues Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 63,
#   'area': 'CONCACAF',
#   'name': 'Nations League - League A',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 343,
#   'area': 'CONCACAF',
#   'name': 'Road to W Gold Cup - Play-Offs',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 212,
#   'area': 'CONCACAF',
#   'name': 'Sudamericano U20',
#   'gender': 'male',
#   'age_group': 'U20'},
#  {'id': 185,
#   'area': 'CONCACAF',
#   'name': 'U20',
#   'gender': 'male',
#   'age_group': 'U20'},
#  {'id': 342,
#   'area': 'CONCACAF',
#   'name': "Women's Gold Cup",
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 337,
#   'area': 'CONCACAF',
#   'name': "Women's U17 Championship",
#   'gender': 'female',
#   'age_group': 'U17'},
#  {'id': 238,
#   'area': 'CONCACAF',
#   'name': "Women's U20 Championship",
#   'gender': 'female',
#   'age_group': 'U20'},
#  {'id': 187,
#   'area': 'CONCACAF',
#   'name': "Women's WC Qualification",
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 51,
#   'area': 'CONMEBOL',
#   'name': 'Copa America',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 109,
#   'area': 'CONMEBOL',
#   'name': 'Copa Libertadores',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 108,
#   'area': 'CONMEBOL',
#   'name': 'Copa Libertadores U20',
#   'gender': 'male',
#   'age_group': 'U20'},
#  {'id': 110,
#   'area': 'CONMEBOL',
#   'name': 'Copa Sudamericana',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 39,
#   'area': 'CONMEBOL',
#   'name': 'FIFA World Cup Qualifier',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 85,
#   'area': 'CONMEBOL',
#   'name': 'Pre-Olympic Tournament',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 344,
#   'area': 'CONMEBOL',
#   'name': 'Recopa Sudamericana',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 93,
#   'area': 'CRO',
#   'name': '1.HNL',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 223,
#   'area': 'CYP',
#   'name': '1. Division',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 94,
#   'area': 'CZE',
#   'name': 'First League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 333,
#   'area': 'CZE',
#   'name': 'FNL',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 145,
#   'area': 'DEN',
#   'name': '1st Division',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 210,
#   'area': 'DEN',
#   'name': 'DBU Pokalen',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 227,
#   'area': 'DEN',
#   'name': 'Kvindeligaen',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 89,
#   'area': 'DEN',
#   'name': 'Superliga',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 205,
#   'area': 'DEN',
#   'name': 'U19 Ligaen',
#   'gender': 'male',
#   'age_group': 'U19'},
#  {'id': 138,
#   'area': 'ECU',
#   'name': 'Liga Pro',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 207,
#   'area': 'EGY',
#   'name': 'Premier League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 66,
#   'area': 'ENG',
#   'name': 'Carabao Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 31,
#   'area': 'ENG',
#   'name': 'Championship',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 54,
#   'area': 'ENG',
#   'name': 'Community Shield',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 96,
#   'area': 'ENG',
#   'name': 'Conference Premier',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 143,
#   'area': 'ENG',
#   'name': 'EFL Trophy',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 19,
#   'area': 'ENG',
#   'name': 'FA Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 127,
#   'area': 'ENG',
#   'name': 'FA Women`s Super League',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 101,
#   'area': 'ENG',
#   'name': 'League One',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 204,
#   'area': 'ENG',
#   'name': 'League Two',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 1,
#   'area': 'ENG',
#   'name': 'Premier League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 79,
#   'area': 'ENG',
#   'name': 'Premier League 2 Division One',
#   'gender': 'male',
#   'age_group': 'U21'},
#  {'id': 155,
#   'area': 'ENG',
#   'name': 'Premier League 2 Division Two',
#   'gender': 'male',
#   'age_group': 'U23'},
#  {'id': 92,
#   'area': 'ENG',
#   'name': 'U18 Premier League',
#   'gender': 'male',
#   'age_group': 'U18'},
#  {'id': 44,
#   'area': 'ESP',
#   'name': 'Copa del Rey',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 208,
#   'area': 'ESP',
#   'name': 'División de Honor Juvenil',
#   'gender': 'male',
#   'age_group': 'U19'},
#  {'id': 4,
#   'area': 'ESP',
#   'name': 'LaLiga',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 42,
#   'area': 'ESP',
#   'name': 'LaLiga 2',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 132,
#   'area': 'ESP',
#   'name': 'Primera División Femenina',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 133,
#   'area': 'ESP',
#   'name': 'Primera Division RFEF',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 116,
#   'area': 'ESP',
#   'name': 'Segunda B',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 134,
#   'area': 'ESP',
#   'name': 'Supercopa',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 130,
#   'area': 'FIFA',
#   'name': 'Confederations Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 189,
#   'area': 'FIFA',
#   'name': "U17 Women's World Cup",
#   'gender': 'female',
#   'age_group': 'U17'},
#  {'id': 327,
#   'area': 'FIFA',
#   'name': 'U17 World Cup',
#   'gender': 'male',
#   'age_group': 'U17'},
#  {'id': 178,
#   'area': 'FIFA',
#   'name': "U20 Women's Wold Cup",
#   'gender': 'female',
#   'age_group': 'U20'},
#  {'id': 237,
#   'area': 'FIFA',
#   'name': 'U20 World Cup',
#   'gender': 'male',
#   'age_group': 'U20'},
#  {'id': 0,
#   'area': 'FIFA',
#   'name': 'World Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 48,
#   'area': 'FIFA',
#   'name': 'World Cup, Women',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 323,
#   'area': 'FIN',
#   'name': 'Veikkausliiga',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 340,
#   'area': 'FRA',
#   'name': 'Championnat National U19',
#   'gender': 'male',
#   'age_group': 'U19'},
#  {'id': 7,
#   'area': 'FRA',
#   'name': 'Coupe de France',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 8,
#   'area': 'FRA',
#   'name': 'Coupe de la Ligue',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 230,
#   'area': 'FRA',
#   'name': 'Feminine Division 1',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 3,
#   'area': 'FRA',
#   'name': 'Ligue 1',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 12,
#   'area': 'FRA',
#   'name': 'Ligue 2',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 30,
#   'area': 'FRA',
#   'name': 'National',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 52,
#   'area': 'FRA',
#   'name': 'Trophée des Champions',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 40,
#   'area': 'GER',
#   'name': '2nd Bundesliga',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 64,
#   'area': 'GER',
#   'name': '3. Liga',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 6,
#   'area': 'GER',
#   'name': 'Bundesliga',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 84,
#   'area': 'GER',
#   'name': 'DFB-Pokal',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 53,
#   'area': 'GER',
#   'name': 'DFL-Supercup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 338,
#   'area': 'GER',
#   'name': 'Frauen Bundesliga',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 325,
#   'area': 'GER',
#   'name': 'Play-offs 1/2',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 326,
#   'area': 'GER',
#   'name': 'Play-offs 2/3',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 142,
#   'area': 'GER',
#   'name': 'Regionalliga',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 135,
#   'area': 'GER',
#   'name': 'U17 Bundesliga',
#   'gender': 'male',
#   'age_group': 'U17'},
#  {'id': 136,
#   'area': 'GER',
#   'name': 'U19 Bundesliga',
#   'gender': 'male',
#   'age_group': 'U19'},
#  {'id': 28,
#   'area': 'GRE',
#   'name': 'Super League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 320,
#   'area': 'GRE',
#   'name': 'Super League 2',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 321,
#   'area': 'GRE',
#   'name': 'Super League K19',
#   'gender': 'male',
#   'age_group': 'U19'},
#  {'id': 98,
#   'area': 'HUN',
#   'name': 'Nemzeti Bajnokság',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 65,
#   'area': 'IND',
#   'name': 'Indian Super League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 184,
#   'area': 'INT',
#   'name': 'Arab Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 215,
#   'area': 'INT',
#   'name': 'Arnold Clark Cup',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 149,
#   'area': 'INT',
#   'name': 'Club Friendlies',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 202,
#   'area': 'INT',
#   'name': 'Finalissima',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 345,
#   'area': 'INT',
#   'name': 'Football Federations Cup U16',
#   'gender': 'male',
#   'age_group': 'U16'},
#  {'id': 20,
#   'area': 'INT',
#   'name': 'Friendly International',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 55,
#   'area': 'INT',
#   'name': 'International Champions Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 179,
#   'area': 'INT',
#   'name': 'Kirin Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 38,
#   'area': 'INT',
#   'name': 'Olympic Games',
#   'gender': 'male',
#   'age_group': 'U23'},
#  {'id': 128,
#   'area': 'INT',
#   'name': 'Olympic Games Women',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 221,
#   'area': 'INT',
#   'name': 'Pinatar National Team Friendlies',
#   'gender': 'male',
#   'age_group': 'U21'},
#  {'id': 186,
#   'area': 'INT',
#   'name': 'SheBelieves Cup',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 188,
#   'area': 'INT',
#   'name': 'Sud Ladies Cup',
#   'gender': 'female',
#   'age_group': 'U20'},
#  {'id': 137,
#   'area': 'INT',
#   'name': 'Syrenka Cup U17',
#   'gender': 'male',
#   'age_group': 'U17'},
#  {'id': 150,
#   'area': 'INT',
#   'name': 'Torneio Internacional Algarve U17',
#   'gender': 'male',
#   'age_group': 'U17'},
#  {'id': 232,
#   'area': 'INT',
#   'name': 'Tournoi de France',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 226,
#   'area': 'INT',
#   'name': 'U16 National Team Friendlies',
#   'gender': 'male',
#   'age_group': 'U16'},
#  {'id': 375,
#   'area': 'INT',
#   'name': 'U17 National Team Friendlies Women',
#   'gender': 'female',
#   'age_group': 'U17'},
#  {'id': 199,
#   'area': 'INT',
#   'name': 'U18 Friendly International',
#   'gender': 'male',
#   'age_group': 'U18'},
#  {'id': 161,
#   'area': 'INT',
#   'name': 'U19 National Team Friendlies',
#   'gender': 'male',
#   'age_group': 'U19'},
#  {'id': 374,
#   'area': 'INT',
#   'name': 'U19 National Team Friendlies Women',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 183,
#   'area': 'INT',
#   'name': 'U20 National Team Friendlies',
#   'gender': 'male',
#   'age_group': 'U20'},
#  {'id': 216,
#   'area': 'INT',
#   'name': 'U21 National Team Friendlies',
#   'gender': 'male',
#   'age_group': 'U21'},
#  {'id': 192,
#   'area': 'INT',
#   'name': 'WC Qualification Intercontinental Play-offs',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 123,
#   'area': 'INT',
#   'name': 'Women Friendly International',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 219,
#   'area': 'INT',
#   'name': "Women's Finalissima",
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 233,
#   'area': 'INT',
#   'name': "Women's WC Qualification Intercontinental Play-off",
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 339,
#   'area': 'INT',
#   'name': 'Yongchuan Tournament',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 220,
#   'area': 'INT',
#   'name': 'Youth Friendlies',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 158,
#   'area': 'IRL',
#   'name': 'First Division',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 406,
#   'area': 'IRL',
#   'name': 'Premier Division',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 310,
#   'area': 'ISL',
#   'name': 'Besta-deild karla',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 309,
#   'area': 'ISL',
#   'name': 'Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 86,
#   'area': 'ISR',
#   'name': 'Ligat Al',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 209,
#   'area': 'ISR',
#   'name': 'State Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 224,
#   'area': 'ITA',
#   'name': 'Campionato Primavera 1',
#   'gender': 'male',
#   'age_group': 'U19'},
#  {'id': 112,
#   'area': 'ITA',
#   'name': 'Coppa Italia',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 5,
#   'area': 'ITA',
#   'name': 'Serie A',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 379,
#   'area': 'ITA',
#   'name': 'Serie A Women',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 41,
#   'area': 'ITA',
#   'name': 'Serie B',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 113,
#   'area': 'ITA',
#   'name': 'Serie C',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 114,
#   'area': 'ITA',
#   'name': 'Serie C, Promotion Playoffs',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 87,
#   'area': 'JPN',
#   'name': 'J1 League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 240,
#   'area': 'JPN',
#   'name': 'J2 League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 348,
#   'area': 'JPN',
#   'name': 'WE League',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 329,
#   'area': 'KAZ',
#   'name': 'Freedom QJ League U18',
#   'gender': 'male',
#   'age_group': 'U18'},
#  {'id': 194,
#   'area': 'KOR',
#   'name': 'K League 1',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 211,
#   'area': 'KOR',
#   'name': 'K League 2',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 231,
#   'area': 'KSA',
#   'name': 'Division 1',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 146,
#   'area': 'KSA',
#   'name': 'Pro League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 222,
#   'area': 'LVA',
#   'name': 'Virsliga',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 409,
#   'area': 'MAR',
#   'name': 'Botola Pro',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 315,
#   'area': 'MEX',
#   'name': 'Liga de Expansión MX',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 97,
#   'area': 'MEX',
#   'name': 'Liga MX',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 336,
#   'area': 'MEX',
#   'name': 'Liga MX Femenil',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 314,
#   'area': 'MEX',
#   'name': 'Liga Premier Serie A',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 173,
#   'area': 'MEX',
#   'name': 'U20 League',
#   'gender': 'male',
#   'age_group': 'U20'},
#  {'id': 172,
#   'area': 'MLT',
#   'name': 'Challenge League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 157,
#   'area': 'MLT',
#   'name': 'Premier League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 106,
#   'area': 'NED',
#   'name': 'Eerste Divisie',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 17,
#   'area': 'NED',
#   'name': 'Eredivisie',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 107,
#   'area': 'NED',
#   'name': 'KNVB Beker',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 124,
#   'area': 'NOR',
#   'name': 'Eliteserien',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 174,
#   'area': 'NOR',
#   'name': 'Obos Ligaen',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 228,
#   'area': 'NOR',
#   'name': 'Toppserien',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 153,
#   'area': 'OFC',
#   'name': 'FIFA World Cup Qualifier',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 140,
#   'area': 'PAR',
#   'name': 'Division Profesional',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 139,
#   'area': 'PER',
#   'name': 'Primera Division',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 43,
#   'area': 'POL',
#   'name': 'Ekstraklasa',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 407,
#   'area': 'POL',
#   'name': 'I liga',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 162,
#   'area': 'POR',
#   'name': 'Liga 3',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 156,
#   'area': 'POR',
#   'name': 'Liga Revelação Sub 23',
#   'gender': 'male',
#   'age_group': 'U23'},
#  {'id': 275,
#   'area': 'POR',
#   'name': 'Play-offs 2/3',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 25,
#   'area': 'POR',
#   'name': 'Primeira Liga',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 102,
#   'area': 'POR',
#   'name': 'Segunda Liga',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 307,
#   'area': 'POR',
#   'name': 'Super Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 274,
#   'area': 'POR',
#   'name': 'Taça da Liga',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 328,
#   'area': 'POR',
#   'name': 'Taça de Portugal',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 152,
#   'area': 'QAT',
#   'name': 'Qatar Stars League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 318,
#   'area': 'QAT',
#   'name': 'QSL Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 104,
#   'area': 'ROU',
#   'name': 'Liga 1',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 377,
#   'area': 'RSA',
#   'name': 'Nedbank Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 165,
#   'area': 'RSA',
#   'name': 'PSL',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 121,
#   'area': 'RUS',
#   'name': 'FNL',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 27,
#   'area': 'RUS',
#   'name': 'Premier League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 171,
#   'area': 'SCO',
#   'name': 'Championship',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 74,
#   'area': 'SCO',
#   'name': 'FA Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 76,
#   'area': 'SCO',
#   'name': 'League Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 170,
#   'area': 'SCO',
#   'name': 'Play-offs 1/2',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 18,
#   'area': 'SCO',
#   'name': 'Premiership',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 105,
#   'area': 'SRB',
#   'name': 'Superliga',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 316,
#   'area': 'SUI',
#   'name': '1. Liga Promotion',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 122,
#   'area': 'SUI',
#   'name': 'Challenge League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 82,
#   'area': 'SUI',
#   'name': 'Super League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 241,
#   'area': 'SVK',
#   'name': 'Niké Liga',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 235,
#   'area': 'SVN',
#   'name': '1. SNL',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 90,
#   'area': 'SWE',
#   'name': 'Allsvenskan',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 229,
#   'area': 'SWE',
#   'name': 'Damallsvenskan',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 312,
#   'area': 'THA',
#   'name': 'Thai League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 120,
#   'area': 'TUR',
#   'name': '1. Lig',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 29,
#   'area': 'TUR',
#   'name': 'Super Lig',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 151,
#   'area': 'UAE',
#   'name': 'Pro League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 378,
#   'area': 'UEFA',
#   'name': 'Baltic Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 10,
#   'area': 'UEFA',
#   'name': 'Champions League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 131,
#   'area': 'UEFA',
#   'name': 'Europa Conference League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 9,
#   'area': 'UEFA',
#   'name': 'Europa League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 2,
#   'area': 'UEFA',
#   'name': 'European Championship',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 34,
#   'area': 'UEFA',
#   'name': 'European Championship Qualifiers',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 15,
#   'area': 'UEFA',
#   'name': 'FIFA World Cup Qualifier',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 21,
#   'area': 'UEFA',
#   'name': 'Nation`s League - League A',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 160,
#   'area': 'UEFA',
#   'name': 'Nation`s League - League B',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 13,
#   'area': 'UEFA',
#   'name': 'Super Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 144,
#   'area': 'UEFA',
#   'name': 'U17 Championship Qualification',
#   'gender': 'male',
#   'age_group': 'U17'},
#  {'id': 163,
#   'area': 'UEFA',
#   'name': 'U17 European Championship',
#   'gender': 'male',
#   'age_group': 'U17'},
#  {'id': 164,
#   'area': 'UEFA',
#   'name': 'U19 European Championship',
#   'gender': 'male',
#   'age_group': 'U19'},
#  {'id': 200,
#   'area': 'UEFA',
#   'name': 'U19 European Championship Qualifiers',
#   'gender': 'male',
#   'age_group': 'U19'},
#  {'id': 218,
#   'area': 'UEFA',
#   'name': 'U20 Elite League',
#   'gender': 'male',
#   'age_group': 'U20'},
#  {'id': 49,
#   'area': 'UEFA',
#   'name': 'U21 European Championship',
#   'gender': 'male',
#   'age_group': 'U21'},
#  {'id': 62,
#   'area': 'UEFA',
#   'name': 'U21 European Championship Qualifiers',
#   'gender': 'male',
#   'age_group': 'U21'},
#  {'id': 141,
#   'area': 'UEFA',
#   'name': 'Women`s Champions League',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 166,
#   'area': 'UEFA',
#   'name': 'Women`s European Championship',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 331,
#   'area': 'UEFA',
#   'name': "Women's Nations League - League A",
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 217,
#   'area': 'UEFA',
#   'name': "Women's WC Qualification Europe",
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 176,
#   'area': 'UEFA',
#   'name': 'Women U17 Championship',
#   'gender': 'female',
#   'age_group': 'U17'},
#  {'id': 177,
#   'area': 'UEFA',
#   'name': 'Women U19 Championship',
#   'gender': 'female',
#   'age_group': 'U19'},
#  {'id': 78,
#   'area': 'UEFA',
#   'name': 'Youth League',
#   'gender': 'male',
#   'age_group': 'U19'},
#  {'id': 26,
#   'area': 'UKR',
#   'name': 'Premier League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 95,
#   'area': 'URU',
#   'name': 'Primera Division',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 60,
#   'area': 'USA',
#   'name': 'Major League Soccer',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 190,
#   'area': 'USA',
#   'name': 'MLS Next Pro',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 126,
#   'area': 'USA',
#   'name': 'NWSL',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 154,
#   'area': 'USA',
#   'name': 'NWSL Challenge Cup',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 191,
#   'area': 'USA',
#   'name': 'USL Championship',
#   'gender': 'male',
#   'age_group': 'adult'}]

# %% [markdown]
# ### Competitions allowed

# %%
competitions = client.get_competitions(params={'user':'true','component_permission_for':'tracking'})

# %%
#competitions

# %%
competitions_editions = client.get_competition_editions(params={'competition_id': 181,'user':'true', 'component_permission_for':'tracking'})

# %%
#competitions_editions

# %% [markdown]
# ### List of matches allowed

# %%
matches = client.get_matches(params={'competition_id': 181,'user':'true', 'component_permission_for':'tracking'})

# %%
matches[:3]
# Out:
# [{'id': 1612245,
#   'date_time': '2024-06-11T18:00:00Z',
#   'home_team': {'id': 367, 'short_name': 'Saudi Arabia'},
#   'away_team': {'id': 645, 'short_name': 'Jordan'},
#   'status': 'not_started'},
#  {'id': 1612246,
#   'date_time': '2024-06-06T17:30:00Z',
#   'home_team': {'id': 645, 'short_name': 'Jordan'},
#   'away_team': {'id': 2226, 'short_name': 'Tajikistan'},
#   'status': 'not_started'},
#  {'id': 1612247,
#   'date_time': '2024-03-26T19:00:00Z',
#   'home_team': {'id': 645, 'short_name': 'Jordan'},
#   'away_team': {'id': 3033, 'short_name': 'Pakistan'},
#   'status': 'not_started'}]

# %% [markdown]
# ### Save tracking Data of a given match

# %% [markdown]
# Saves the data into a jsonl file

# %%
client.save_match_tracking_data(match_id=matches[0]['id'],filepath=str(matches[0]['id'])+'.jsonl')

# %% [markdown]
# ### Match Data

# %%
match_data = client.get_match(match_id=matches[0]['id'])
match_data
# Out:
# {'id': 1612245,
#  'home_team_score': 1,
#  'away_team_score': 2,
#  'date_time': '2024-06-11T18:00:00Z',
#  'stadium': {'id': 640,
#   'name': 'King Saud University Stadium',
#   'city': 'Riyadh',
#   'capacity': None},
#  'home_team': {'id': 367,
#   'name': 'Saudi Arabia',
#   'short_name': 'Saudi Arabia',
#   'acronym': 'SAU'},
#  'home_team_kit': {'id': 292,
#   'team_id': 367,
#   'season': {'id': 4,
#    'start_year': 2017,
#    'end_year': 2018,
#    'name': '2017/2018'},
#   'name': 'away',
#   'jersey_color': '#2d8c20',
#   'number_color': '#ffffff'},
#  'away_team': {'id': 645,
#   'name': 'Jordan',
#   'short_name': 'Jordan',
#   'acronym': 'JOR'},
#  'away_team_kit': {'id': 8172,
#   'team_id': 645,
#   'season': {'id': 21,
#    'start_year': 2022,
#    'end_year': 2023,
#    'name': '2022/2023'},
#   'name': 'Home',
#   'jersey_color': '#fafafa',
#   'number_color': '#000000'},
#  'home_team_coach': {'id': 26,
#   'first_name': 'Juan Antonio',
#   'last_name': 'Pizzi'},
#  'away_team_coach': {'id': 469,
#   'first_name': 'Abdulla',
#   'last_name': 'Mesfer'},
#  'competition_edition': {'id': 858,
#   'competition': {'id': 181,
#    'area': 'AFC',
#    'name': 'WC Qualification Asia',
#    'gender': 'male',
#    'age_group': 'adult'},
#   'season': {'id': 28,
#    'start_year': 2023,
#    'end_year': 2024,
#    'name': '2023/2024'},
#   'name': 'AFC - WC Qualification Asia - 2023/2024'},
#  'competition_round': {'id': 2559,
#   'name': 'Round 6',
#   'round_number': 6,
#   'potential_overtime': False},
#  'referees': [],
#  'players': [{'player_role': {'id': 2,
#     'position_group': 'Central Defender',
#     'name': 'Center Back',
#     'acronym': 'CB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 4,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 1,
#    'own_goal': 0,
#    'team_player_id': 928220,
#    'team_id': 367,
#    'id': 81407,
#    'first_name': 'Ali',
#    'last_name': 'Al Lajami ',
#    'short_name': 'Ali Lajami',
#    'birthday': '1996-04-24',
#    'trackable_object': 82540,
#    'gender': 'male'},
#   {'player_role': {'id': 9,
#     'position_group': 'Midfield',
#     'name': 'Left Midfield',
#     'acronym': 'LM'},
#    'start_time': '00:00:00',
#    'end_time': '01:36:40',
#    'number': 8,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 1,
#    'own_goal': 0,
#    'team_player_id': 219015,
#    'team_id': 645,
#    'id': 90528,
#    'first_name': 'Noor Al-Deen Mahmoud Ali',
#    'last_name': 'Al Rawabdeh',
#    'short_name': 'Noor Al Rawabdeh',
#    'birthday': '1997-02-24',
#    'trackable_object': 91662,
#    'gender': 'male'},
#   {'player_role': {'id': 9,
#     'position_group': 'Midfield',
#     'name': 'Left Midfield',
#     'acronym': 'LM'},
#    'start_time': '01:36:40',
#    'end_time': None,
#    'number': 14,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 219019,
#    'team_id': 645,
#    'id': 74272,
#    'first_name': 'Rajaei Ayed Fadel',
#    'last_name': 'Hasan',
#    'short_name': 'Rajaei Ayed',
#    'birthday': '1993-07-25',
#    'trackable_object': 75402,
#    'gender': 'male'},
#   {'player_role': {'id': 13,
#     'position_group': 'Wide Attacker',
#     'name': 'Right Winger',
#     'acronym': 'RW'},
#    'start_time': '00:00:00',
#    'end_time': '01:36:40',
#    'number': 10,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 219042,
#    'team_id': 645,
#    'id': 13818,
#    'first_name': 'Mousa Mohammad Suleiman',
#    'last_name': 'Al Tamari',
#    'short_name': 'Mousa Al Tamari',
#    'birthday': '1997-06-10',
#    'trackable_object': 14015,
#    'gender': 'male'},
#   {'player_role': {'id': 12,
#     'position_group': 'Wide Attacker',
#     'name': 'Left Winger',
#     'acronym': 'LW'},
#    'start_time': '01:36:40',
#    'end_time': None,
#    'number': 18,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1275023,
#    'team_id': 645,
#    'id': 828997,
#    'first_name': 'Mahmoud Shawkat',
#    'last_name': 'Aqel Musleh',
#    'short_name': 'Mahmoud Shawkat',
#    'birthday': '1995-05-20',
#    'trackable_object': 830560,
#    'gender': 'male'},
#   {'player_role': {'id': 12,
#     'position_group': 'Wide Attacker',
#     'name': 'Left Winger',
#     'acronym': 'LW'},
#    'start_time': '00:00:00',
#    'end_time': '01:20:57',
#    'number': 9,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 1,
#    'own_goal': 0,
#    'team_player_id': 219023,
#    'team_id': 645,
#    'id': 90535,
#    'first_name': 'Ali Iyad Ali',
#    'last_name': 'Al Olwan',
#    'short_name': 'Ali Olwan',
#    'birthday': '2000-03-26',
#    'trackable_object': 91669,
#    'gender': 'male'},
#   {'player_role': {'id': 12,
#     'position_group': 'Wide Attacker',
#     'name': 'Left Winger',
#     'acronym': 'LW'},
#    'start_time': '01:20:57',
#    'end_time': None,
#    'number': 20,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1234772,
#    'team_id': 645,
#    'id': 74283,
#    'first_name': 'Mohannad Nahmoud Saleh',
#    'last_name': 'Abu Taha',
#    'short_name': 'Mohannad Abu Taha',
#    'birthday': '2003-02-02',
#    'trackable_object': 75413,
#    'gender': 'male'},
#   {'player_role': {'id': 10,
#     'position_group': 'Midfield',
#     'name': 'Right Midfield',
#     'acronym': 'RM'},
#    'start_time': '00:00:00',
#    'end_time': '01:12:01',
#    'number': 21,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1234769,
#    'team_id': 645,
#    'id': 783534,
#    'first_name': 'Nizar Mahmoud Ahmed',
#    'last_name': 'Al Rashdan',
#    'short_name': 'Nizar Al Rashdan',
#    'birthday': '1999-03-23',
#    'trackable_object': 785097,
#    'gender': 'male'},
#   {'player_role': {'id': 5,
#     'position_group': 'Full Back',
#     'name': 'Left Wing Back',
#     'acronym': 'LWB'},
#    'start_time': '01:12:01',
#    'end_time': None,
#    'number': 2,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 219006,
#    'team_id': 645,
#    'id': 90523,
#    'first_name': 'Mohammad Ali',
#    'last_name': 'Hasan Abu Hasheesh',
#    'short_name': 'Mohammad Abu Hasheesh',
#    'birthday': '1995-05-09',
#    'trackable_object': 91657,
#    'gender': 'male'},
#   {'player_role': {'id': 5,
#     'position_group': 'Full Back',
#     'name': 'Left Wing Back',
#     'acronym': 'LWB'},
#    'start_time': '00:00:00',
#    'end_time': '01:12:01',
#    'number': 13,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 219017,
#    'team_id': 645,
#    'id': 90530,
#    'first_name': 'Mahmoud Nayef Ahmad',
#    'last_name': 'Al Mardi',
#    'short_name': 'Mahmoud Al Mardi',
#    'birthday': '1993-10-06',
#    'trackable_object': 91664,
#    'gender': 'male'},
#   {'player_role': {'id': 10,
#     'position_group': 'Midfield',
#     'name': 'Right Midfield',
#     'acronym': 'RM'},
#    'start_time': '01:12:01',
#    'end_time': None,
#    'number': 15,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 219018,
#    'team_id': 645,
#    'id': 90531,
#    'first_name': 'Ibrahim Mohammad Sami',
#    'last_name': 'Saadeh',
#    'short_name': 'Ibrahim Saadeh',
#    'birthday': '2000-04-27',
#    'trackable_object': 91665,
#    'gender': 'male'},
#   {'player_role': {'id': 15,
#     'position_group': 'Center Forward',
#     'name': 'Center Forward',
#     'acronym': 'CF'},
#    'start_time': '00:00:00',
#    'end_time': '01:25:26',
#    'number': 10,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 6104,
#    'team_id': 367,
#    'id': 11941,
#    'first_name': 'Salem Mohammed',
#    'last_name': 'Al Dawsari',
#    'short_name': 'Salem Al Dawsari',
#    'birthday': '1991-08-19',
#    'trackable_object': 12048,
#    'gender': 'male'},
#   {'player_role': {'id': 7,
#     'position_group': 'Midfield',
#     'name': 'Defensive Midfield',
#     'acronym': 'DM'},
#    'start_time': '01:25:26',
#    'end_time': None,
#    'number': 7,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1234824,
#    'team_id': 367,
#    'id': 14382,
#    'first_name': 'Mukhtar',
#    'last_name': 'Ali Shaikh',
#    'short_name': 'Mukhtar Ali',
#    'birthday': '1997-10-30',
#    'trackable_object': 14579,
#    'gender': 'male'},
#   {'player_role': {'id': 15,
#     'position_group': 'Center Forward',
#     'name': 'Center Forward',
#     'acronym': 'CF'},
#    'start_time': '00:00:00',
#    'end_time': '01:02:50',
#    'number': 9,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 223034,
#    'team_id': 367,
#    'id': 164086,
#    'first_name': 'Firas Tariq',
#    'last_name': 'Al Buraikan',
#    'short_name': 'Firas Al Buraikan',
#    'birthday': '2000-05-14',
#    'trackable_object': 165641,
#    'gender': 'male'},
#   {'player_role': {'id': 15,
#     'position_group': 'Center Forward',
#     'name': 'Center Forward',
#     'acronym': 'CF'},
#    'start_time': '01:02:50',
#    'end_time': None,
#    'number': 18,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 14889,
#    'team_id': 367,
#    'id': 17875,
#    'first_name': 'Abdulrahman',
#    'last_name': 'Ghareeb',
#    'short_name': 'Abdulrahman Ghareeb',
#    'birthday': '1997-03-31',
#    'trackable_object': 18072,
#    'gender': 'male'},
#   {'player_role': {'id': 7,
#     'position_group': 'Midfield',
#     'name': 'Defensive Midfield',
#     'acronym': 'DM'},
#    'start_time': '00:00:00',
#    'end_time': '01:02:50',
#    'number': 15,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 6091,
#    'team_id': 367,
#    'id': 11928,
#    'first_name': 'Abdullah',
#    'last_name': 'Al Khaibari',
#    'short_name': 'Abdullah Al Khaibari',
#    'birthday': '1996-08-16',
#    'trackable_object': 12035,
#    'gender': 'male'},
#   {'player_role': {'id': 15,
#     'position_group': 'Center Forward',
#     'name': 'Center Forward',
#     'acronym': 'CF'},
#    'start_time': '01:02:50',
#    'end_time': None,
#    'number': 11,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 223052,
#    'team_id': 367,
#    'id': 72901,
#    'first_name': 'Abdullah Hadi',
#    'last_name': 'Radif',
#    'short_name': 'Abdullah Radif',
#    'birthday': '2003-01-20',
#    'trackable_object': 74028,
#    'gender': 'male'},
#   {'player_role': {'id': 5,
#     'position_group': 'Full Back',
#     'name': 'Left Wing Back',
#     'acronym': 'LWB'},
#    'start_time': '00:00:00',
#    'end_time': '00:45:03',
#    'number': 6,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 223056,
#    'team_id': 367,
#    'id': 72900,
#    'first_name': 'Nasser',
#    'last_name': 'Al Dawsari',
#    'short_name': 'Nasser Al Dawsari',
#    'birthday': '1998-12-19',
#    'trackable_object': 74027,
#    'gender': 'male'},
#   {'player_role': {'id': 5,
#     'position_group': 'Full Back',
#     'name': 'Left Wing Back',
#     'acronym': 'LWB'},
#    'start_time': '00:45:03',
#    'end_time': None,
#    'number': 13,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 223025,
#    'team_id': 367,
#    'id': 155062,
#    'first_name': 'Moteb Saad Salem',
#    'last_name': 'Al Harbi',
#    'short_name': 'Moteb Al Harbi',
#    'birthday': '2000-02-20',
#    'trackable_object': 156617,
#    'gender': 'male'},
#   {'player_role': {'id': 0,
#     'position_group': 'Other',
#     'name': 'Goalkeeper',
#     'acronym': 'GK'},
#    'start_time': '00:00:00',
#    'end_time': '00:34:29',
#    'number': 21,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 6076,
#    'team_id': 367,
#    'id': 11914,
#    'first_name': 'Mohammed Khalil',
#    'last_name': 'Al Owais',
#    'short_name': 'Mohammed Al Owais',
#    'birthday': '1991-10-10',
#    'trackable_object': 12021,
#    'gender': 'male'},
#   {'player_role': {'id': 0,
#     'position_group': 'Other',
#     'name': 'Goalkeeper',
#     'acronym': 'GK'},
#    'start_time': '00:34:29',
#    'end_time': None,
#    'number': 22,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1234822,
#    'team_id': 367,
#    'id': 72920,
#    'first_name': 'Ahmed Ali',
#    'last_name': 'Al Kassar',
#    'short_name': 'Ahmed Al Kassar',
#    'birthday': '1991-05-08',
#    'trackable_object': 74047,
#    'gender': 'male'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 6,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1234773,
#    'team_id': 645,
#    'id': 783538,
#    'first_name': 'Yousef',
#    'last_name': 'Abu Jalboush',
#    'short_name': 'Yousef Abu Jalboush',
#    'birthday': '1998-06-15',
#    'trackable_object': 785101,
#    'gender': 'male'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 19,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1275022,
#    'team_id': 645,
#    'id': 828995,
#    'first_name': 'Saed Ahmad Salameh',
#    'last_name': 'Al Rosan',
#    'short_name': 'Saed Al Rosan',
#    'birthday': '1997-02-01',
#    'trackable_object': 830558,
#    'gender': 'male'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 12,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1275021,
#    'team_id': 645,
#    'id': 783537,
#    'first_name': 'Noureddin Zaid',
#    'last_name': 'Khaleel Bani Ateyah',
#    'short_name': 'Noureddin Zaid',
#    'birthday': '1993-01-25',
#    'trackable_object': 785100,
#    'gender': 'male'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 16,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 219045,
#    'team_id': 645,
#    'id': 74477,
#    'first_name': 'Feras Zeyad',
#    'last_name': 'Yousef Shelbaieh',
#    'short_name': 'Feras Shelbaieh',
#    'birthday': '1993-11-27',
#    'trackable_object': 75607,
#    'gender': 'male'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 4,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 219040,
#    'team_id': 645,
#    'id': 90547,
#    'first_name': "Bara' Sami Mousa",
#    'last_name': 'Marei',
#    'short_name': "Bara' Marei",
#    'birthday': '1994-04-13',
#    'trackable_object': 91681,
#    'gender': 'male'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 7,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1275024,
#    'team_id': 645,
#    'id': 783530,
#    'first_name': 'Aref',
#    'last_name': 'Al Haj',
#    'short_name': 'Aref Al Haj',
#    'birthday': '2001-05-28',
#    'trackable_object': 785093,
#    'gender': 'male'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 22,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1234770,
#    'team_id': 645,
#    'id': 810218,
#    'first_name': 'Ahmed Muhannad Talib',
#    'last_name': 'Al Jaeidi',
#    'short_name': 'Ahmed Al Jaeidi',
#    'birthday': '2001-04-09',
#    'trackable_object': 811781,
#    'gender': 'male'},
#   {'player_role': {'id': 0,
#     'position_group': 'Other',
#     'name': 'Goalkeeper',
#     'acronym': 'GK'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 1,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 219003,
#    'team_id': 645,
#    'id': 90520,
#    'first_name': 'Yazeed Moien Hasan',
#    'last_name': 'Abulaila',
#    'short_name': 'Yazeed Abulaila',
#    'birthday': '1993-01-08',
#    'trackable_object': 91654,
#    'gender': 'male'},
#   {'player_role': {'id': 15,
#     'position_group': 'Center Forward',
#     'name': 'Center Forward',
#     'acronym': 'CF'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 11,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 219022,
#    'team_id': 645,
#    'id': 90534,
#    'first_name': 'Yazan Abdallah',
#    'last_name': 'Ayed Al Naimat',
#    'short_name': 'Yazan Al Naimat',
#    'birthday': '1999-06-04',
#    'trackable_object': 91668,
#    'gender': 'male'},
#   {'player_role': {'id': 2,
#     'position_group': 'Central Defender',
#     'name': 'Center Back',
#     'acronym': 'CB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 5,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 219008,
#    'team_id': 645,
#    'id': 74278,
#    'first_name': 'Yazan Mousa Mahmoud Abu',
#    'last_name': 'Al Arab',
#    'short_name': 'Yazan Al Arab',
#    'birthday': '1996-01-31',
#    'trackable_object': 75408,
#    'gender': 'male'},
#   {'player_role': {'id': 3,
#     'position_group': 'Central Defender',
#     'name': 'Left Center Back',
#     'acronym': 'LCB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 17,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 219036,
#    'team_id': 645,
#    'id': 90544,
#    'first_name': 'Salem Mahmoud Suleiman',
#    'last_name': 'Al Ajalin',
#    'short_name': 'Salem Al Ajalin',
#    'birthday': '1988-02-18',
#    'trackable_object': 91678,
#    'gender': 'male'},
#   {'player_role': {'id': 6,
#     'position_group': 'Full Back',
#     'name': 'Right Wing Back',
#     'acronym': 'RWB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 23,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 219013,
#    'team_id': 645,
#    'id': 80323,
#    'first_name': 'Ehsan Nabil Farhan',
#    'last_name': 'Haddad',
#    'short_name': 'Ehsan Haddad',
#    'birthday': '1994-02-05',
#    'trackable_object': 81455,
#    'gender': 'male'},
#   {'player_role': {'id': 4,
#     'position_group': 'Central Defender',
#     'name': 'Right Center Back',
#     'acronym': 'RCB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 3,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 418718,
#    'team_id': 645,
#    'id': 74280,
#    'first_name': 'Abdallah Mousa',
#    'last_name': 'Musallam Naseeb',
#    'short_name': 'Abdallah Naseeb',
#    'birthday': '1994-02-25',
#    'trackable_object': 75410,
#    'gender': 'male'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 2,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 223039,
#    'team_id': 367,
#    'id': 73626,
#    'first_name': 'Sultan Abdullah',
#    'last_name': 'Al Ghannam',
#    'short_name': 'Sultan Al Ghannam',
#    'birthday': '1994-05-06',
#    'trackable_object': 74756,
#    'gender': 'male'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 16,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 223031,
#    'team_id': 367,
#    'id': 73635,
#    'first_name': 'Sami Khalil Nasser',
#    'last_name': 'Al Naji',
#    'short_name': 'Sami Al Naji',
#    'birthday': '1997-02-07',
#    'trackable_object': 74765,
#    'gender': 'male'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 1,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1234825,
#    'team_id': 367,
#    'id': 80398,
#    'first_name': 'Raghid',
#    'last_name': 'Al Najjar',
#    'short_name': 'Raghid Al Najjar',
#    'birthday': '1996-07-01',
#    'trackable_object': 81530,
#    'gender': 'male'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 20,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1275744,
#    'team_id': 367,
#    'id': 737573,
#    'first_name': 'Marwan',
#    'last_name': 'Al Sahafi',
#    'short_name': 'Marwan Al Sahafi',
#    'birthday': '2004-02-17',
#    'trackable_object': 739136,
#    'gender': 'male'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 14,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1234828,
#    'team_id': 367,
#    'id': 732132,
#    'first_name': 'Hassan',
#    'last_name': 'Kadesh Mahboob',
#    'short_name': 'Hassan Kadesh',
#    'birthday': '1992-09-26',
#    'trackable_object': 733695,
#    'gender': 'male'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 3,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1234826,
#    'team_id': 367,
#    'id': 159999,
#    'first_name': 'Awn Mutlaq',
#    'last_name': 'Al Saluli',
#    'short_name': 'Awn Al Saluli',
#    'birthday': '1998-09-02',
#    'trackable_object': 161554,
#    'gender': 'male'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 19,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1275741,
#    'team_id': 367,
#    'id': 795220,
#    'first_name': 'Abbas Sadiq',
#    'last_name': 'Al Hassan',
#    'short_name': 'Abbas Al Hassan',
#    'birthday': '2004-02-22',
#    'trackable_object': 796783,
#    'gender': 'male'},
#   {'player_role': {'id': 6,
#     'position_group': 'Full Back',
#     'name': 'Right Wing Back',
#     'acronym': 'RWB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 12,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 223021,
#    'team_id': 367,
#    'id': 143765,
#    'first_name': 'Saud Abdullah Salim',
#    'last_name': 'Abdulhamid',
#    'short_name': 'Saud Abdulhamid',
#    'birthday': '1999-07-18',
#    'trackable_object': 145320,
#    'gender': 'male'},
#   {'player_role': {'id': 4,
#     'position_group': 'Central Defender',
#     'name': 'Right Center Back',
#     'acronym': 'RCB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 17,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1234867,
#    'team_id': 367,
#    'id': 734064,
#    'first_name': 'Rayan Hamed',
#    'last_name': 'Hamidou',
#    'short_name': 'Rayan Hamidou',
#    'birthday': '2002-04-13',
#    'trackable_object': 735627,
#    'gender': 'male'},
#   {'player_role': {'id': 9,
#     'position_group': 'Midfield',
#     'name': 'Left Midfield',
#     'acronym': 'LM'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 8,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1275742,
#    'team_id': 367,
#    'id': 72908,
#    'first_name': 'Musab Fahz',
#    'last_name': 'Al Juwayr',
#    'short_name': 'Musab Al Juwayr',
#    'birthday': '2003-06-20',
#    'trackable_object': 74035,
#    'gender': 'male'},
#   {'player_role': {'id': 10,
#     'position_group': 'Midfield',
#     'name': 'Right Midfield',
#     'acronym': 'RM'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 23,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 6101,
#    'team_id': 367,
#    'id': 11938,
#    'first_name': 'Mohammed',
#    'last_name': 'Kanno',
#    'short_name': 'Mohamed Kanno',
#    'birthday': '1994-09-22',
#    'trackable_object': 12045,
#    'gender': 'male'},
#   {'player_role': {'id': 3,
#     'position_group': 'Central Defender',
#     'name': 'Left Center Back',
#     'acronym': 'LCB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 5,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 6090,
#    'team_id': 367,
#    'id': 11927,
#    'first_name': 'Ali Hadi Mohammed',
#    'last_name': 'Al Bulayhi',
#    'short_name': 'Ali Al Bulayhi',
#    'birthday': '1989-11-21',
#    'trackable_object': 12034,
#    'gender': 'male'}],
#  'status': 'not_started',
#  'home_team_side': ['right_to_left', 'left_to_right'],
#  'ball': {'trackable_object': 55},
#  'pitch_length': 105,
#  'pitch_width': 68}

# %%
match_data.keys()
# Out:
# dict_keys(['id', 'home_team_score', 'away_team_score', 'date_time', 'stadium', 'home_team', 'home_team_kit', 'away_team', 'away_team_kit', 'home_team_coach', 'away_team_coach', 'competition_edition', 'competition_round', 'referees', 'players', 'status', 'home_team_side', 'ball', 'pitch_length', 'pitch_width'])

# %%
# types of data
for k,v in match_data.items():
    print(k+" : ",type(v).__name__)
# Out:
# id :  int
# home_team_score :  int
# away_team_score :  int
# date_time :  str
# stadium :  dict
# home_team :  dict
# home_team_kit :  dict
# away_team :  dict
# away_team_kit :  dict
# home_team_coach :  dict
# away_team_coach :  dict
# competition_edition :  dict
# competition_round :  dict
# referees :  list
# players :  list
# status :  str
# home_team_side :  list
# ball :  dict
# pitch_length :  int
# pitch_width :  int

# %% [markdown]
# #### Players list

# %%
len(match_data['players'])
# Out:
# 46

# %%
match_data['players']
# Out:
# [{'player_role': {'id': 2,
#    'position_group': 'Central Defender',
#    'name': 'Center Back',
#    'acronym': 'CB'},
#   'start_time': '00:00:00',
#   'end_time': None,
#   'number': 4,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 1,
#   'own_goal': 0,
#   'team_player_id': 928220,
#   'team_id': 367,
#   'id': 81407,
#   'first_name': 'Ali',
#   'last_name': 'Al Lajami ',
#   'short_name': 'Ali Lajami',
#   'birthday': '1996-04-24',
#   'trackable_object': 82540,
#   'gender': 'male'},
#  {'player_role': {'id': 9,
#    'position_group': 'Midfield',
#    'name': 'Left Midfield',
#    'acronym': 'LM'},
#   'start_time': '00:00:00',
#   'end_time': '01:36:40',
#   'number': 8,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 1,
#   'own_goal': 0,
#   'team_player_id': 219015,
#   'team_id': 645,
#   'id': 90528,
#   'first_name': 'Noor Al-Deen Mahmoud Ali',
#   'last_name': 'Al Rawabdeh',
#   'short_name': 'Noor Al Rawabdeh',
#   'birthday': '1997-02-24',
#   'trackable_object': 91662,
#   'gender': 'male'},
#  {'player_role': {'id': 9,
#    'position_group': 'Midfield',
#    'name': 'Left Midfield',
#    'acronym': 'LM'},
#   'start_time': '01:36:40',
#   'end_time': None,
#   'number': 14,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 219019,
#   'team_id': 645,
#   'id': 74272,
#   'first_name': 'Rajaei Ayed Fadel',
#   'last_name': 'Hasan',
#   'short_name': 'Rajaei Ayed',
#   'birthday': '1993-07-25',
#   'trackable_object': 75402,
#   'gender': 'male'},
#  {'player_role': {'id': 13,
#    'position_group': 'Wide Attacker',
#    'name': 'Right Winger',
#    'acronym': 'RW'},
#   'start_time': '00:00:00',
#   'end_time': '01:36:40',
#   'number': 10,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 219042,
#   'team_id': 645,
#   'id': 13818,
#   'first_name': 'Mousa Mohammad Suleiman',
#   'last_name': 'Al Tamari',
#   'short_name': 'Mousa Al Tamari',
#   'birthday': '1997-06-10',
#   'trackable_object': 14015,
#   'gender': 'male'},
#  {'player_role': {'id': 12,
#    'position_group': 'Wide Attacker',
#    'name': 'Left Winger',
#    'acronym': 'LW'},
#   'start_time': '01:36:40',
#   'end_time': None,
#   'number': 18,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1275023,
#   'team_id': 645,
#   'id': 828997,
#   'first_name': 'Mahmoud Shawkat',
#   'last_name': 'Aqel Musleh',
#   'short_name': 'Mahmoud Shawkat',
#   'birthday': '1995-05-20',
#   'trackable_object': 830560,
#   'gender': 'male'},
#  {'player_role': {'id': 12,
#    'position_group': 'Wide Attacker',
#    'name': 'Left Winger',
#    'acronym': 'LW'},
#   'start_time': '00:00:00',
#   'end_time': '01:20:57',
#   'number': 9,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 1,
#   'own_goal': 0,
#   'team_player_id': 219023,
#   'team_id': 645,
#   'id': 90535,
#   'first_name': 'Ali Iyad Ali',
#   'last_name': 'Al Olwan',
#   'short_name': 'Ali Olwan',
#   'birthday': '2000-03-26',
#   'trackable_object': 91669,
#   'gender': 'male'},
#  {'player_role': {'id': 12,
#    'position_group': 'Wide Attacker',
#    'name': 'Left Winger',
#    'acronym': 'LW'},
#   'start_time': '01:20:57',
#   'end_time': None,
#   'number': 20,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1234772,
#   'team_id': 645,
#   'id': 74283,
#   'first_name': 'Mohannad Nahmoud Saleh',
#   'last_name': 'Abu Taha',
#   'short_name': 'Mohannad Abu Taha',
#   'birthday': '2003-02-02',
#   'trackable_object': 75413,
#   'gender': 'male'},
#  {'player_role': {'id': 10,
#    'position_group': 'Midfield',
#    'name': 'Right Midfield',
#    'acronym': 'RM'},
#   'start_time': '00:00:00',
#   'end_time': '01:12:01',
#   'number': 21,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1234769,
#   'team_id': 645,
#   'id': 783534,
#   'first_name': 'Nizar Mahmoud Ahmed',
#   'last_name': 'Al Rashdan',
#   'short_name': 'Nizar Al Rashdan',
#   'birthday': '1999-03-23',
#   'trackable_object': 785097,
#   'gender': 'male'},
#  {'player_role': {'id': 5,
#    'position_group': 'Full Back',
#    'name': 'Left Wing Back',
#    'acronym': 'LWB'},
#   'start_time': '01:12:01',
#   'end_time': None,
#   'number': 2,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 219006,
#   'team_id': 645,
#   'id': 90523,
#   'first_name': 'Mohammad Ali',
#   'last_name': 'Hasan Abu Hasheesh',
#   'short_name': 'Mohammad Abu Hasheesh',
#   'birthday': '1995-05-09',
#   'trackable_object': 91657,
#   'gender': 'male'},
#  {'player_role': {'id': 5,
#    'position_group': 'Full Back',
#    'name': 'Left Wing Back',
#    'acronym': 'LWB'},
#   'start_time': '00:00:00',
#   'end_time': '01:12:01',
#   'number': 13,
#   'yellow_card': 1,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 219017,
#   'team_id': 645,
#   'id': 90530,
#   'first_name': 'Mahmoud Nayef Ahmad',
#   'last_name': 'Al Mardi',
#   'short_name': 'Mahmoud Al Mardi',
#   'birthday': '1993-10-06',
#   'trackable_object': 91664,
#   'gender': 'male'},
#  {'player_role': {'id': 10,
#    'position_group': 'Midfield',
#    'name': 'Right Midfield',
#    'acronym': 'RM'},
#   'start_time': '01:12:01',
#   'end_time': None,
#   'number': 15,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 219018,
#   'team_id': 645,
#   'id': 90531,
#   'first_name': 'Ibrahim Mohammad Sami',
#   'last_name': 'Saadeh',
#   'short_name': 'Ibrahim Saadeh',
#   'birthday': '2000-04-27',
#   'trackable_object': 91665,
#   'gender': 'male'},
#  {'player_role': {'id': 15,
#    'position_group': 'Center Forward',
#    'name': 'Center Forward',
#    'acronym': 'CF'},
#   'start_time': '00:00:00',
#   'end_time': '01:25:26',
#   'number': 10,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 6104,
#   'team_id': 367,
#   'id': 11941,
#   'first_name': 'Salem Mohammed',
#   'last_name': 'Al Dawsari',
#   'short_name': 'Salem Al Dawsari',
#   'birthday': '1991-08-19',
#   'trackable_object': 12048,
#   'gender': 'male'},
#  {'player_role': {'id': 7,
#    'position_group': 'Midfield',
#    'name': 'Defensive Midfield',
#    'acronym': 'DM'},
#   'start_time': '01:25:26',
#   'end_time': None,
#   'number': 7,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1234824,
#   'team_id': 367,
#   'id': 14382,
#   'first_name': 'Mukhtar',
#   'last_name': 'Ali Shaikh',
#   'short_name': 'Mukhtar Ali',
#   'birthday': '1997-10-30',
#   'trackable_object': 14579,
#   'gender': 'male'},
#  {'player_role': {'id': 15,
#    'position_group': 'Center Forward',
#    'name': 'Center Forward',
#    'acronym': 'CF'},
#   'start_time': '00:00:00',
#   'end_time': '01:02:50',
#   'number': 9,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 223034,
#   'team_id': 367,
#   'id': 164086,
#   'first_name': 'Firas Tariq',
#   'last_name': 'Al Buraikan',
#   'short_name': 'Firas Al Buraikan',
#   'birthday': '2000-05-14',
#   'trackable_object': 165641,
#   'gender': 'male'},
#  {'player_role': {'id': 15,
#    'position_group': 'Center Forward',
#    'name': 'Center Forward',
#    'acronym': 'CF'},
#   'start_time': '01:02:50',
#   'end_time': None,
#   'number': 18,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 14889,
#   'team_id': 367,
#   'id': 17875,
#   'first_name': 'Abdulrahman',
#   'last_name': 'Ghareeb',
#   'short_name': 'Abdulrahman Ghareeb',
#   'birthday': '1997-03-31',
#   'trackable_object': 18072,
#   'gender': 'male'},
#  {'player_role': {'id': 7,
#    'position_group': 'Midfield',
#    'name': 'Defensive Midfield',
#    'acronym': 'DM'},
#   'start_time': '00:00:00',
#   'end_time': '01:02:50',
#   'number': 15,
#   'yellow_card': 1,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 6091,
#   'team_id': 367,
#   'id': 11928,
#   'first_name': 'Abdullah',
#   'last_name': 'Al Khaibari',
#   'short_name': 'Abdullah Al Khaibari',
#   'birthday': '1996-08-16',
#   'trackable_object': 12035,
#   'gender': 'male'},
#  {'player_role': {'id': 15,
#    'position_group': 'Center Forward',
#    'name': 'Center Forward',
#    'acronym': 'CF'},
#   'start_time': '01:02:50',
#   'end_time': None,
#   'number': 11,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 223052,
#   'team_id': 367,
#   'id': 72901,
#   'first_name': 'Abdullah Hadi',
#   'last_name': 'Radif',
#   'short_name': 'Abdullah Radif',
#   'birthday': '2003-01-20',
#   'trackable_object': 74028,
#   'gender': 'male'},
#  {'player_role': {'id': 5,
#    'position_group': 'Full Back',
#    'name': 'Left Wing Back',
#    'acronym': 'LWB'},
#   'start_time': '00:00:00',
#   'end_time': '00:45:03',
#   'number': 6,
#   'yellow_card': 1,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 223056,
#   'team_id': 367,
#   'id': 72900,
#   'first_name': 'Nasser',
#   'last_name': 'Al Dawsari',
#   'short_name': 'Nasser Al Dawsari',
#   'birthday': '1998-12-19',
#   'trackable_object': 74027,
#   'gender': 'male'},
#  {'player_role': {'id': 5,
#    'position_group': 'Full Back',
#    'name': 'Left Wing Back',
#    'acronym': 'LWB'},
#   'start_time': '00:45:03',
#   'end_time': None,
#   'number': 13,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 223025,
#   'team_id': 367,
#   'id': 155062,
#   'first_name': 'Moteb Saad Salem',
#   'last_name': 'Al Harbi',
#   'short_name': 'Moteb Al Harbi',
#   'birthday': '2000-02-20',
#   'trackable_object': 156617,
#   'gender': 'male'},
#  {'player_role': {'id': 0,
#    'position_group': 'Other',
#    'name': 'Goalkeeper',
#    'acronym': 'GK'},
#   'start_time': '00:00:00',
#   'end_time': '00:34:29',
#   'number': 21,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 6076,
#   'team_id': 367,
#   'id': 11914,
#   'first_name': 'Mohammed Khalil',
#   'last_name': 'Al Owais',
#   'short_name': 'Mohammed Al Owais',
#   'birthday': '1991-10-10',
#   'trackable_object': 12021,
#   'gender': 'male'},
#  {'player_role': {'id': 0,
#    'position_group': 'Other',
#    'name': 'Goalkeeper',
#    'acronym': 'GK'},
#   'start_time': '00:34:29',
#   'end_time': None,
#   'number': 22,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1234822,
#   'team_id': 367,
#   'id': 72920,
#   'first_name': 'Ahmed Ali',
#   'last_name': 'Al Kassar',
#   'short_name': 'Ahmed Al Kassar',
#   'birthday': '1991-05-08',
#   'trackable_object': 74047,
#   'gender': 'male'},
#  {'player_role': {'id': 17,
#    'position_group': 'Other',
#    'name': 'Substitute',
#    'acronym': 'SUB'},
#   'start_time': None,
#   'end_time': None,
#   'number': 6,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1234773,
#   'team_id': 645,
#   'id': 783538,
#   'first_name': 'Yousef',
#   'last_name': 'Abu Jalboush',
#   'short_name': 'Yousef Abu Jalboush',
#   'birthday': '1998-06-15',
#   'trackable_object': 785101,
#   'gender': 'male'},
#  {'player_role': {'id': 17,
#    'position_group': 'Other',
#    'name': 'Substitute',
#    'acronym': 'SUB'},
#   'start_time': None,
#   'end_time': None,
#   'number': 19,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1275022,
#   'team_id': 645,
#   'id': 828995,
#   'first_name': 'Saed Ahmad Salameh',
#   'last_name': 'Al Rosan',
#   'short_name': 'Saed Al Rosan',
#   'birthday': '1997-02-01',
#   'trackable_object': 830558,
#   'gender': 'male'},
#  {'player_role': {'id': 17,
#    'position_group': 'Other',
#    'name': 'Substitute',
#    'acronym': 'SUB'},
#   'start_time': None,
#   'end_time': None,
#   'number': 12,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1275021,
#   'team_id': 645,
#   'id': 783537,
#   'first_name': 'Noureddin Zaid',
#   'last_name': 'Khaleel Bani Ateyah',
#   'short_name': 'Noureddin Zaid',
#   'birthday': '1993-01-25',
#   'trackable_object': 785100,
#   'gender': 'male'},
#  {'player_role': {'id': 17,
#    'position_group': 'Other',
#    'name': 'Substitute',
#    'acronym': 'SUB'},
#   'start_time': None,
#   'end_time': None,
#   'number': 16,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 219045,
#   'team_id': 645,
#   'id': 74477,
#   'first_name': 'Feras Zeyad',
#   'last_name': 'Yousef Shelbaieh',
#   'short_name': 'Feras Shelbaieh',
#   'birthday': '1993-11-27',
#   'trackable_object': 75607,
#   'gender': 'male'},
#  {'player_role': {'id': 17,
#    'position_group': 'Other',
#    'name': 'Substitute',
#    'acronym': 'SUB'},
#   'start_time': None,
#   'end_time': None,
#   'number': 4,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 219040,
#   'team_id': 645,
#   'id': 90547,
#   'first_name': "Bara' Sami Mousa",
#   'last_name': 'Marei',
#   'short_name': "Bara' Marei",
#   'birthday': '1994-04-13',
#   'trackable_object': 91681,
#   'gender': 'male'},
#  {'player_role': {'id': 17,
#    'position_group': 'Other',
#    'name': 'Substitute',
#    'acronym': 'SUB'},
#   'start_time': None,
#   'end_time': None,
#   'number': 7,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1275024,
#   'team_id': 645,
#   'id': 783530,
#   'first_name': 'Aref',
#   'last_name': 'Al Haj',
#   'short_name': 'Aref Al Haj',
#   'birthday': '2001-05-28',
#   'trackable_object': 785093,
#   'gender': 'male'},
#  {'player_role': {'id': 17,
#    'position_group': 'Other',
#    'name': 'Substitute',
#    'acronym': 'SUB'},
#   'start_time': None,
#   'end_time': None,
#   'number': 22,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1234770,
#   'team_id': 645,
#   'id': 810218,
#   'first_name': 'Ahmed Muhannad Talib',
#   'last_name': 'Al Jaeidi',
#   'short_name': 'Ahmed Al Jaeidi',
#   'birthday': '2001-04-09',
#   'trackable_object': 811781,
#   'gender': 'male'},
#  {'player_role': {'id': 0,
#    'position_group': 'Other',
#    'name': 'Goalkeeper',
#    'acronym': 'GK'},
#   'start_time': '00:00:00',
#   'end_time': None,
#   'number': 1,
#   'yellow_card': 1,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 219003,
#   'team_id': 645,
#   'id': 90520,
#   'first_name': 'Yazeed Moien Hasan',
#   'last_name': 'Abulaila',
#   'short_name': 'Yazeed Abulaila',
#   'birthday': '1993-01-08',
#   'trackable_object': 91654,
#   'gender': 'male'},
#  {'player_role': {'id': 15,
#    'position_group': 'Center Forward',
#    'name': 'Center Forward',
#    'acronym': 'CF'},
#   'start_time': '00:00:00',
#   'end_time': None,
#   'number': 11,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 219022,
#   'team_id': 645,
#   'id': 90534,
#   'first_name': 'Yazan Abdallah',
#   'last_name': 'Ayed Al Naimat',
#   'short_name': 'Yazan Al Naimat',
#   'birthday': '1999-06-04',
#   'trackable_object': 91668,
#   'gender': 'male'},
#  {'player_role': {'id': 2,
#    'position_group': 'Central Defender',
#    'name': 'Center Back',
#    'acronym': 'CB'},
#   'start_time': '00:00:00',
#   'end_time': None,
#   'number': 5,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 219008,
#   'team_id': 645,
#   'id': 74278,
#   'first_name': 'Yazan Mousa Mahmoud Abu',
#   'last_name': 'Al Arab',
#   'short_name': 'Yazan Al Arab',
#   'birthday': '1996-01-31',
#   'trackable_object': 75408,
#   'gender': 'male'},
#  {'player_role': {'id': 3,
#    'position_group': 'Central Defender',
#    'name': 'Left Center Back',
#    'acronym': 'LCB'},
#   'start_time': '00:00:00',
#   'end_time': None,
#   'number': 17,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 219036,
#   'team_id': 645,
#   'id': 90544,
#   'first_name': 'Salem Mahmoud Suleiman',
#   'last_name': 'Al Ajalin',
#   'short_name': 'Salem Al Ajalin',
#   'birthday': '1988-02-18',
#   'trackable_object': 91678,
#   'gender': 'male'},
#  {'player_role': {'id': 6,
#    'position_group': 'Full Back',
#    'name': 'Right Wing Back',
#    'acronym': 'RWB'},
#   'start_time': '00:00:00',
#   'end_time': None,
#   'number': 23,
#   'yellow_card': 1,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 219013,
#   'team_id': 645,
#   'id': 80323,
#   'first_name': 'Ehsan Nabil Farhan',
#   'last_name': 'Haddad',
#   'short_name': 'Ehsan Haddad',
#   'birthday': '1994-02-05',
#   'trackable_object': 81455,
#   'gender': 'male'},
#  {'player_role': {'id': 4,
#    'position_group': 'Central Defender',
#    'name': 'Right Center Back',
#    'acronym': 'RCB'},
#   'start_time': '00:00:00',
#   'end_time': None,
#   'number': 3,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 418718,
#   'team_id': 645,
#   'id': 74280,
#   'first_name': 'Abdallah Mousa',
#   'last_name': 'Musallam Naseeb',
#   'short_name': 'Abdallah Naseeb',
#   'birthday': '1994-02-25',
#   'trackable_object': 75410,
#   'gender': 'male'},
#  {'player_role': {'id': 17,
#    'position_group': 'Other',
#    'name': 'Substitute',
#    'acronym': 'SUB'},
#   'start_time': None,
#   'end_time': None,
#   'number': 2,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 223039,
#   'team_id': 367,
#   'id': 73626,
#   'first_name': 'Sultan Abdullah',
#   'last_name': 'Al Ghannam',
#   'short_name': 'Sultan Al Ghannam',
#   'birthday': '1994-05-06',
#   'trackable_object': 74756,
#   'gender': 'male'},
#  {'player_role': {'id': 17,
#    'position_group': 'Other',
#    'name': 'Substitute',
#    'acronym': 'SUB'},
#   'start_time': None,
#   'end_time': None,
#   'number': 16,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 223031,
#   'team_id': 367,
#   'id': 73635,
#   'first_name': 'Sami Khalil Nasser',
#   'last_name': 'Al Naji',
#   'short_name': 'Sami Al Naji',
#   'birthday': '1997-02-07',
#   'trackable_object': 74765,
#   'gender': 'male'},
#  {'player_role': {'id': 17,
#    'position_group': 'Other',
#    'name': 'Substitute',
#    'acronym': 'SUB'},
#   'start_time': None,
#   'end_time': None,
#   'number': 1,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1234825,
#   'team_id': 367,
#   'id': 80398,
#   'first_name': 'Raghid',
#   'last_name': 'Al Najjar',
#   'short_name': 'Raghid Al Najjar',
#   'birthday': '1996-07-01',
#   'trackable_object': 81530,
#   'gender': 'male'},
#  {'player_role': {'id': 17,
#    'position_group': 'Other',
#    'name': 'Substitute',
#    'acronym': 'SUB'},
#   'start_time': None,
#   'end_time': None,
#   'number': 20,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1275744,
#   'team_id': 367,
#   'id': 737573,
#   'first_name': 'Marwan',
#   'last_name': 'Al Sahafi',
#   'short_name': 'Marwan Al Sahafi',
#   'birthday': '2004-02-17',
#   'trackable_object': 739136,
#   'gender': 'male'},
#  {'player_role': {'id': 17,
#    'position_group': 'Other',
#    'name': 'Substitute',
#    'acronym': 'SUB'},
#   'start_time': None,
#   'end_time': None,
#   'number': 14,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1234828,
#   'team_id': 367,
#   'id': 732132,
#   'first_name': 'Hassan',
#   'last_name': 'Kadesh Mahboob',
#   'short_name': 'Hassan Kadesh',
#   'birthday': '1992-09-26',
#   'trackable_object': 733695,
#   'gender': 'male'},
#  {'player_role': {'id': 17,
#    'position_group': 'Other',
#    'name': 'Substitute',
#    'acronym': 'SUB'},
#   'start_time': None,
#   'end_time': None,
#   'number': 3,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1234826,
#   'team_id': 367,
#   'id': 159999,
#   'first_name': 'Awn Mutlaq',
#   'last_name': 'Al Saluli',
#   'short_name': 'Awn Al Saluli',
#   'birthday': '1998-09-02',
#   'trackable_object': 161554,
#   'gender': 'male'},
#  {'player_role': {'id': 17,
#    'position_group': 'Other',
#    'name': 'Substitute',
#    'acronym': 'SUB'},
#   'start_time': None,
#   'end_time': None,
#   'number': 19,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1275741,
#   'team_id': 367,
#   'id': 795220,
#   'first_name': 'Abbas Sadiq',
#   'last_name': 'Al Hassan',
#   'short_name': 'Abbas Al Hassan',
#   'birthday': '2004-02-22',
#   'trackable_object': 796783,
#   'gender': 'male'},
#  {'player_role': {'id': 6,
#    'position_group': 'Full Back',
#    'name': 'Right Wing Back',
#    'acronym': 'RWB'},
#   'start_time': '00:00:00',
#   'end_time': None,
#   'number': 12,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 223021,
#   'team_id': 367,
#   'id': 143765,
#   'first_name': 'Saud Abdullah Salim',
#   'last_name': 'Abdulhamid',
#   'short_name': 'Saud Abdulhamid',
#   'birthday': '1999-07-18',
#   'trackable_object': 145320,
#   'gender': 'male'},
#  {'player_role': {'id': 4,
#    'position_group': 'Central Defender',
#    'name': 'Right Center Back',
#    'acronym': 'RCB'},
#   'start_time': '00:00:00',
#   'end_time': None,
#   'number': 17,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1234867,
#   'team_id': 367,
#   'id': 734064,
#   'first_name': 'Rayan Hamed',
#   'last_name': 'Hamidou',
#   'short_name': 'Rayan Hamidou',
#   'birthday': '2002-04-13',
#   'trackable_object': 735627,
#   'gender': 'male'},
#  {'player_role': {'id': 9,
#    'position_group': 'Midfield',
#    'name': 'Left Midfield',
#    'acronym': 'LM'},
#   'start_time': '00:00:00',
#   'end_time': None,
#   'number': 8,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 1275742,
#   'team_id': 367,
#   'id': 72908,
#   'first_name': 'Musab Fahz',
#   'last_name': 'Al Juwayr',
#   'short_name': 'Musab Al Juwayr',
#   'birthday': '2003-06-20',
#   'trackable_object': 74035,
#   'gender': 'male'},
#  {'player_role': {'id': 10,
#    'position_group': 'Midfield',
#    'name': 'Right Midfield',
#    'acronym': 'RM'},
#   'start_time': '00:00:00',
#   'end_time': None,
#   'number': 23,
#   'yellow_card': 0,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 6101,
#   'team_id': 367,
#   'id': 11938,
#   'first_name': 'Mohammed',
#   'last_name': 'Kanno',
#   'short_name': 'Mohamed Kanno',
#   'birthday': '1994-09-22',
#   'trackable_object': 12045,
#   'gender': 'male'},
#  {'player_role': {'id': 3,
#    'position_group': 'Central Defender',
#    'name': 'Left Center Back',
#    'acronym': 'LCB'},
#   'start_time': '00:00:00',
#   'end_time': None,
#   'number': 5,
#   'yellow_card': 1,
#   'red_card': 0,
#   'injured': False,
#   'goal': 0,
#   'own_goal': 0,
#   'team_player_id': 6090,
#   'team_id': 367,
#   'id': 11927,
#   'first_name': 'Ali Hadi Mohammed',
#   'last_name': 'Al Bulayhi',
#   'short_name': 'Ali Al Bulayhi',
#   'birthday': '1989-11-21',
#   'trackable_object': 12034,
#   'gender': 'male'}]
